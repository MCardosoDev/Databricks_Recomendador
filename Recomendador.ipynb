# %%
dbutils.fs.ls("dbfs:/FileStore/dados")

# %%
caminho_data = "dbfs:/FileStore/dados/data.csv"

# %%
df_data = spark.read.csv(caminho_data, inferSchema=True, header=True)

# %%
df_data.show(5)

# %%
type(df_data)

# %%
df_data = df_data.pandas_api()

# %%
type(df_data)

# %%
df_data.head()

# %%
df_data.info()

# %%
colunas_float = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']
colunas_int = ['duration_ms', 'mode', 'key', 'explicit', 'popularity']

# %%
df_data[colunas_float] = df_data[colunas_float].astype(float)
df_data[colunas_int] = df_data[colunas_int].astype(int)

# %%
df_data.info()

# %%
df_data.head()

# %%
type(df_data.artists.iloc[0])

# %%
X = df_data.iloc[0:9]
X

# %%
X['artists'] = X.artists.str.replace("\[|\]|\'", "")
X['artists'] = X.artists.str.replace(",", ";")

# %%
X

# %%
df_data['artists'] = df_data.artists.str.replace("\[|\]|\'", "")
df_data['artists'] = df_data.artists.str.replace(",", ";")

# %%
df_data.head()

# %%
dbutils.fs.ls('dbfs:/FileStore')

# %%
dbutils.fs.mkdirs('dbfs:/FileStore/dados_tratados')

# %%
dbutils.fs.ls('dbfs:/FileStore')

# %%
df_data.to_parquet('dbfs:/FileStore/dados_tratados/data.parquet')

# %%
dbutils.fs.ls('dbfs:/FileStore/dados_tratados')

# %%
df_data_artist = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.option("sep", ',') \
.load("dbfs:/FileStore/dados/data_by_artist.csv")

# %%
df_data_artist = df_data_artist.pandas_api()

# %%
df_data_artist[['acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','popularity']] = df_data_artist[['acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','popularity']].astype(float)

# %%
df_data_artist['artists'] = df_data_artist['artists'].str.replace('[','')
df_data_artist['artists'] = df_data_artist['artists'].str.replace(']','')
df_data_artist['artists'] = df_data_artist['artists'].str.replace("'", "")
df_data_artist['artists'] = df_data_artist['artists'].str.replace('"', '')
df_data_artist['artists'] = df_data_artist['artists'].str.replace(",", ";")

# %%
path="dbfs:/FileStore/dados_tratados/data_artist.parquet"
df_data_artist.to_parquet(path)

# %%
df_data_genres = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.option("sep", ',') \
.load("dbfs:/FileStore/dados/data_by_genres.csv")

# %%
df_data_genres = df_data_genres.pandas_api()

# %%
df_data_genres[['acousticness', 'danceability', 'duration_ms','energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']] = df_data_genres[['acousticness', 'danceability', 'duration_ms','energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']].astype(float)

# %%
path="dbfs:/FileStore/dados_tratados/data_genres.parquet"
df_data_genres.to_parquet(path)

# %%
df_data_year = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.option("sep", ',') \
.load("dbfs:/FileStore/dados/data_by_year.csv")

# %%
df_data_year = df_data_year.pandas_api()

# %%
df_data_year[['acousticness', 'danceability', 'duration_ms', 'energy','instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo','valence', 'popularity']] = df_data_year[['acousticness', 'danceability', 'duration_ms', 'energy','instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo','valence', 'popularity']].astype(float)

# %%
path="dbfs:/FileStore/dados_tratados/data_year.parquet"
df_data_year.to_parquet(path)

# %%
df_data_Wgenres = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.load("dbfs:/FileStore/dados/data_w_genres.csv")

# %%
df_data_Wgenres = df_data_Wgenres.pandas_api()

# %%
df_data_Wgenres[['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']] = df_data_Wgenres[['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']].astype(float)

# %%
df_data_Wgenres[['key', 'mode', 'count']] = df_data_Wgenres[['key', 'mode', 'count']].astype(int)

# %%
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace('[','')
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace(']','')
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace("'", "")
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace('"', '')
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace(",", ";")

# %%
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace('[','')
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace(']','')
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace("'", "")
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace('"', '')
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace(",", ";")

# %%
path="dbfs:/FileStore/dados_tratados/data_w_genres.parquet"
df_data_Wgenres.to_parquet(path)

# %%
import pyspark.pandas as ps

# %%
path = 'dbfs:/FileStore/dados_tratados/data.parquet/'
df_data = ps.read_parquet(path)
df_data.head()

# %%
path = 'dbfs:/FileStore/dados_tratados/data.parquet/'
df_data = ps.read_parquet(path)
df_data.head()

# %%
df_data.describe()

# %%
len(df_data.year.unique())

# %%
df_data.year.value_counts()

# %%
df_data.year.value_counts().sort_index()

# %%
df_data.year.value_counts().sort_index().plot.bar()

# %%
df_data['decade'] = df_data.year.apply(lambda year: f'{(year//10)*10}s')

# %%
df_data.head()

# %%
df_data_2 = df_data[['decade']]
df_data_2['qtd'] = 1

# %%
df_data_2 = df_data_2.groupby('decade').sum()
df_data_2

# %%
df_data_2.sort_index().plot.bar(y='qtd')

# %%
dbutils.fs.ls("dbfs:/FileStore/dados_tratados")

# %%
path = 'dbfs:/FileStore/dados_tratados/data_year.parquet'
df_year = ps.read_parquet(path)
df_year.head()

# %%
len(df_year.year.unique())

# %%
df_year.plot.line(x='year', y='duration_ms')

# %%
df_year.plot.line(x='year', y=['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence'])

# %%
df_year['decade'] = df_year['year'].apply(lambda row: f'{(row//10)*10}s')
df_year['qtd'] = 1

# %%
df_year_2 = df_year.groupby('decade').agg({
    'acousticness': 'mean',
    'danceability': 'mean',
    'duration_ms': 'mean',
    'energy': 'mean',
    'instrumentalness': 'mean',
    'liveness': 'mean',
    'loudness': 'mean',
    'speechiness': 'mean', 
    'tempo': 'mean',
    'valence': 'mean', 
    'popularity': 'mean',
    'qtd': 'sum' }).sort_index().reset_index()

# %%
df_year_2.plot.line(x='decade', y=['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence'])

# %% [markdown]
# Perguntas
# * 1 - Quais são os 10 top artistas ?
# * 2 - Qual o gênero musical dos 10 top artistas ?
# * 3 - Quais são os 10 top gêneros ?
# * 4 - Quais artistas então nos 10 top gêneros

# %%
dbutils.fs.ls("dbfs:/FileStore/dados_tratados")

# %%
df_genres = ps.read_parquet('dbfs:/FileStore/dados_tratados/data_genres.parquet/')
df_artists = ps.read_parquet('dbfs:/FileStore/dados_tratados/data_artist.parquet/')
df_Wgenres = ps.read_parquet('dbfs:/FileStore/dados_tratados/data_w_genres.parquet/')

# %%
df_artists.head()

# %%
artista_ordenado = df_artists.sort_values(by='count', ascending=False)
artista_ordenado.head()

# %%
top_artista = artista_ordenado.iloc[0:10]
top_artista

# %%
plot_title = 'Top 10 Artistas'
top_artista.plot.bar(x='count', y = 'artists', title = plot_title)

# %%
lista_artistas = top_artista.artists.unique().to_list()
lista_artistas

# %%
artista_genero = df_Wgenres.loc[df_Wgenres['artists'].isin(lista_artistas)]
artista_genero = artista_genero[['genres', 'artists']]
display(artista_genero)

# %%
df_Wgenres['qtd'] = 1
df_Wgenres_2 = df_Wgenres[['genres', 'qtd']]
Wgenres_2_ordenado = df_Wgenres_2.groupby('genres').sum().sort_values(by='qtd', ascending=False).reset_index()
top_generos = Wgenres_2_ordenado.loc[0:10]

# %%
plot_title = 'Top 10 Gêneros'
top_generos.plot.bar(x='qtd', y='genres', title=plot_title)

# %%
top_generos_2 = Wgenres_2_ordenado.loc[1:11]
plot_title = 'Top 10 Gêneros'
top_generos_2.plot.bar(x='qtd', y='genres', title=plot_title)

# %%
lista_genero =  top_generos_2.genres.unique().to_list()
genero_artista = df_Wgenres.loc[df_Wgenres['genres'].isin (lista_genero)]
genero_artista = genero_artista[['genres', 'artists' ]]
display(genero_artista)

# %%
path = 'dbfs:/FileStore/dados_tratados/data.parquet'
df_data = ps.read_parquet(path)

# %%
df_data.info()

# %%
df_data = df_data.dropna()

# %%
df_data.info()

# %%
df_data['artists_song'] = df_data.artists + ' - ' + df_data.name

# %%
df_data.head(5)

# %%
df_data.info()

# %%
X = df_data.columns.to_list()
X.remove('artists')
X.remove('id')
X.remove('name')
X.remove('artists_song')
X.remove('release_date')
X

# %%
df_data = df_data.to_spark()

# %%
from pyspark.ml.feature import VectorAssembler

# %%
dados_encoded_vector = VectorAssembler(inputCols=X, outputCol='features').transform(df_data)

# %%
dados_encoded_vector.select('features').show(truncate=False, n=5)

# %%
from pyspark.ml.feature import StandardScaler

# %%
scaler = StandardScaler(inputCol='features', outputCol='features_scaled')
model_scaler = scaler.fit(dados_encoded_vector)
dados_musicas_scaler = model_scaler.transform(dados_encoded_vector)

# %%
dados_musicas_scaler.select('features_scaled').show(truncate=False, n=5)

# %%
k = len(X)
k

# %%
from pyspark.ml.feature import PCA

# %%
pca = PCA(k=k, inputCol='features_scaled', outputCol='pca_features')
model_pca = pca.fit(dados_musicas_scaler)
dados_musicas_pca = model_pca.transform(dados_musicas_scaler)

# %%
model_pca.explainedVariance

# %%
sum(model_pca.explainedVariance) * 100

# %%
lista_valores = [sum(model_pca.explainedVariance[0:i+1]) for i in range(k)]
lista_valores

# %%
import numpy as np

# %%
k = sum(np.array(lista_valores) <= 0.7)
k

# %%
pca = PCA(k=k, inputCol='features_scaled', outputCol='pca_features')
model_pca = pca.fit(dados_musicas_scaler)
dados_musicas_pca_final = model_pca.transform(dados_musicas_scaler)

# %%
dados_musicas_pca_final.select('pca_features').show(truncate=False, n=5)

# %%
from pyspark.ml import Pipeline

# %%
pca_pipeline = Pipeline(stages=[VectorAssembler(inputCols=X, outputCol='features'),
                                StandardScaler(inputCol='features', outputCol='features_scaled'),
                                PCA(k=6, inputCol='features_scaled', outputCol='pca_features')])

# %%
model_pca_pipeline = pca_pipeline.fit(df_data)

# %%
projection = model_pca_pipeline.transform(df_data)

# %%
projection.select('pca_features').show(truncate=False, n=5)

# %%
from pyspark.ml.clustering import KMeans

# %%
SEED = 1224

# %%
kmeans = KMeans(k=50, featuresCol='pca_features', predictionCol='cluster_pca', seed=SEED)

# %%
modelo_kmeans = kmeans.fit(projection)

# %%
projetion_kmeans = modelo_kmeans.transform(projection)

# %%
projetion_kmeans.select(['pca_features','cluster_pca']).show()

# %%
from pyspark.ml.functions import vector_to_array

# %%
projetion_kmeans = projetion_kmeans.withColumn('x', vector_to_array('pca_features')[0])\
                                   .withColumn('y', vector_to_array('pca_features')[1])

# %%
projetion_kmeans.select(['x', 'y', 'cluster_pca', 'artists_song']).show()

# %%
import plotly.express as px

# %%
fig = px.scatter(projetion_kmeans.toPandas(), x='x', y='y', color='cluster_pca', hover_data=['artists_song'])
fig.show()

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
# from pyspark.ml.linalg import Vectors
from pyspark.sql.functions import rand

data = spark.createDataFrame([(Vectors.dense([0.0, 0.0]),), (Vectors.dense([1.0, 1.0]),),
                              (Vectors.dense([9.0, 8.0]),), (Vectors.dense([8.0, 9.0]),)], ['features']).orderBy(rand())

kmeans = KMeans(k=2, seed=1)
model = kmeans.fit(data)

# evaluator = SilhouetteEvaluator()
evaluator = ClusteringEvaluator()
silhouette = evaluator.evaluate(model.transform(data))
print(f"Silhouette score: {silhouette}")

# %%
import matplotlib.pyplot as plt
from pyspark.ml.linalg import Vectors

data = spark.createDataFrame([(Vectors.dense([0.0, 0.0]),), (Vectors.dense([1.0, 1.0]),),
                              (Vectors.dense([9.0, 8.0]),), (Vectors.dense([8.0, 9.0]),)], ['features']).orderBy(rand())

silhouette_scores = []
k_values = range(2, 6)
for k in k_values:
    kmeans = KMeans(k=k, seed=1)
    model = kmeans.fit(data)
    evaluator = ClusteringEvaluator()
    silhouette_scores.append(evaluator.evaluate(model.transform(data)))

plt.plot(k_values, silhouette_scores, '-o')
plt.xlabel('Número de Clusters')
plt.ylabel('Score de Silhueta')
plt.show()

# %%
nome_musica = 'Taylor Swift - Blank Space'

# %%
cluster = projetion_kmeans.filter(projetion_kmeans.artists_song == nome_musica).select('cluster_pca').collect()[0][0]
cluster

# %%
musicas_recomendadas = projetion_kmeans.filter(projetion_kmeans.cluster_pca == cluster)\
                                       .select('artists_song', 'id', 'pca_features')
musicas_recomendadas.show()

# %%
componenetes_musica = musicas_recomendadas.filter(musicas_recomendadas.artists_song == nome_musica)\
                                          .select('pca_features').collect()[0][0]
componenetes_musica

# %%
from scipy.spatial.distance import euclidean
from pyspark.sql.types import FloatType
import pyspark.sql.functions as f

# %%
def calcula_distance(value):
    return euclidean(componenetes_musica, value)

udf_calcula_distance = f.udf(calcula_distance, FloatType())
musicas_recomendadas_dist = musicas_recomendadas.withColumn('Dist', udf_calcula_distance('pca_features'))

# %%
recomendadas = spark.createDataFrame(musicas_recomendadas_dist.sort('Dist').take(10)).select(['artists_song', 'id', 'Dist'])
recomendadas.show()

# %%
def recomendador(nome_musica):
    cluster = projetion_kmeans.filter(projetion_kmeans.artists_song == nome_musica).select('cluster_pca').collect()[0][0]
    musicas_recomendadas = projetion_kmeans.filter(projetion_kmeans.cluster_pca == cluster)\
                                       .select('artists_song', 'id', 'pca_features')
    componenetes_musica = musicas_recomendadas.filter(musicas_recomendadas.artists_song == nome_musica)\
                                          .select('pca_features').collect()[0][0]
    
    def calcula_distance(value):
        return euclidean(componenetes_musica, value)

    udf_calcula_distance = f.udf(calcula_distance, FloatType())
    musicas_recomendadas_dist = musicas_recomendadas.withColumn('Dist', udf_calcula_distance('pca_features'))
    recomendadas = spark.createDataFrame(musicas_recomendadas_dist.sort('Dist').take(10)).select(['artists_song', 'id', 'Dist'])

    return recomendadas

# %%
df_recomedada = recomendador('Taylor Swift - Blank Space')
df_recomedada.show()

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth, SpotifyClientCredentials

# %%
scope = "user-library-read playlist-modify-private"

OAuth = SpotifyOAuth(
        scope=scope,         
        redirect_uri='http://localhost:5000/callback',
        client_id = '',
        client_secret = '')

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = '', client_secret ='')
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
id = projetion_kmeans.filter(projetion_kmeans.artists_song == nome_musica).select('id').collect()[0][0]
id

# %%
sp.track(id)

# %%
playlist_id = df_recomedada.select('id').collect()

# %%
playlist_track = []
for id in playlist_id:
    playlist_track.append(sp.track(id[0]))

# %%
def recomendador(nome_musica):
    cluster = projetion_kmeans.filter(projetion_kmeans.artists_song == nome_musica).select('cluster_pca').collect()[0][0]
    musicas_recomendadas = projetion_kmeans.filter(projetion_kmeans.cluster_pca == cluster)\
                                       .select('artists_song', 'id', 'pca_features')
    componenetes_musica = musicas_recomendadas.filter(musicas_recomendadas.artists_song == nome_musica)\
                                          .select('pca_features').collect()[0][0]
    
    def calcula_distance(value):
        return euclidean(componenetes_musica, value)

    udf_calcula_distance = f.udf(calcula_distance, FloatType())
    musicas_recomendadas_dist = musicas_recomendadas.withColumn('Dist', udf_calcula_distance('pca_features'))
    recomendadas = spark.createDataFrame(musicas_recomendadas_dist.sort('Dist').take(10)).select(['artists_song', 'id', 'Dist'])
    id = projetion_kmeans.filter(projetion_kmeans.artists_song == nome_musica).select('id').collect()[0][0]
    playlist_id = recomendadas.select('id').collect()
    playlist_track = []

    for id in playlist_id:
        playlist_track.append(sp.track(id[0]))

    return len(playlist_track)

# %%
recomendador('Taylor Swift - Blank Space')

# %%
# !pip install scikit-image

# %%
from skimage import io

nome_musica = 'Taylor Swift - Blank Space'

id = projetion_kmeans\
          .filter(projetion_kmeans.artists_song == nome_musica)\
          .select('id').collect()[0][0]

track = sp.track(id)
url = track["album"]["images"][1]["url"]
name = track["name"]
image = io.imread(url)
plt.imshow(image)
plt.xlabel(name, fontsize = 10)
plt.show()

# %%
def visualize_songs(name,url):

    plt.figure(figsize=(15,10))
    columns = 5
    for i, u in enumerate(url):
        ax = plt.subplot(len(url) // columns + 1, columns, i + 1)
        image = io.imread(u)
        plt.imshow(image)
        ax.get_yaxis().set_visible(False)
        plt.xticks(color = 'w', fontsize = 0.1)
        plt.yticks(color = 'w', fontsize = 0.1)
        plt.xlabel(name[i], fontsize = 10)
        plt.tight_layout(h_pad=0.7, w_pad=0)
        plt.subplots_adjust(wspace=None, hspace=None)
        plt.grid(visible=None)
    plt.show()

# %%
playlist_id = df_recomedada.select('id').collect()

name = []
url = []
for i in playlist_id:
    track = sp.track(i[0])
    url.append(track["album"]["images"][1]["url"])
    name.append(track["name"])

# %%
visualize_songs(name,url)

# %%
def recomendador(nome_musica):
    cluster = projetion_kmeans.filter(projetion_kmeans.artists_song == nome_musica).select('cluster_pca').collect()[0][0]
    musicas_recomendadas = projetion_kmeans.filter(projetion_kmeans.cluster_pca == cluster)\
                                       .select('artists_song', 'id', 'pca_features')
    componenetes_musica = musicas_recomendadas.filter(musicas_recomendadas.artists_song == nome_musica)\
                                          .select('pca_features').collect()[0][0]

    def calcula_distance(value):
        return euclidean(componenetes_musica, value)

    udf_calcula_distance = f.udf(calcula_distance, FloatType())
    musicas_recomendadas_dist = musicas_recomendadas.withColumn('Dist', udf_calcula_distance('pca_features'))
    recomendadas = spark.createDataFrame(musicas_recomendadas_dist.sort('Dist').take(10)).select(['artists_song', 'id', 'Dist'])
    playlist_id = recomendadas.select('id').collect()
    name = []
    url = []
    for i in playlist_id:
        track = sp.track(i[0])
        url.append(track["album"]["images"][1]["url"])
        name.append(track["name"])

    plt.figure(figsize=(15,10))
    columns = 5
    for i, u in enumerate(url):
        ax = plt.subplot(len(url) // columns + 1, columns, i + 1)
        image = io.imread(u)
        plt.imshow(image)
        ax.get_yaxis().set_visible(False)
        plt.xticks(color = 'w', fontsize = 0.1)
        plt.yticks(color = 'w', fontsize = 0.1)
        plt.xlabel(name[i], fontsize = 10)
        plt.tight_layout(h_pad=0.7, w_pad=0)
        plt.subplots_adjust(wspace=None, hspace=None)
        plt.grid(visible=None)
    plt.show()

# %%
recomendador('Taylor Swift - Blank Space')
